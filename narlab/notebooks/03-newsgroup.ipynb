# %% [markdown]
# ## NewsGroup Classification
# 1) Importing Libraries
# 2) Importing and Trasnforming Data
# 3) Experimenting ML Pipelines
# 4) E2E ML Pipeline

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import numpy as np
from collections import Counter

from sklearn.datasets import fetch_20newsgroups
from sklearn.datasets import fetch_20newsgroups_vectorized
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# ### Importing and Trasnforming Data

# %%
newsgroups = fetch_20newsgroups(subset='train')

# %%
Counter([newsgroups.target_names[x] for x in newsgroups.target])
# Out:
# Counter({'rec.autos': 594,
#          'comp.sys.mac.hardware': 578,
#          'comp.graphics': 584,
#          'sci.space': 593,
#          'talk.politics.guns': 546,
#          'sci.med': 594,
#          'comp.sys.ibm.pc.hardware': 590,
#          'comp.os.ms-windows.misc': 591,
#          'rec.motorcycles': 598,
#          'talk.religion.misc': 377,
#          'misc.forsale': 585,
#          'alt.atheism': 480,
#          'sci.electronics': 591,
#          'comp.windows.x': 593,
#          'rec.sport.hockey': 600,
#          'rec.sport.baseball': 597,
#          'soc.religion.christian': 599,
#          'talk.politics.mideast': 564,
#          'talk.politics.misc': 465,
#          'sci.crypt': 595})

# %%
Counter([newsgroups.target_names[x].split('.')[0] for x in newsgroups.target])
# Out:
# Counter({'rec': 2389,
#          'comp': 2936,
#          'sci': 2373,
#          'talk': 1952,
#          'misc': 585,
#          'alt': 480,
#          'soc': 599})

# %%
X_train, X_test, y_train, y_test = train_test_split(newsgroups.data, newsgroups.target, test_size=0.4, random_state=42)

# %%
le = LabelEncoder()
y_train_tr = le.fit_transform(y_train)
y_test_tr = le.transform(y_test)

# %%
tfidf = TfidfVectorizer(stop_words=list(ENGLISH_STOP_WORDS), max_features=100)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
countvec = CountVectorizer(stop_words=list(ENGLISH_STOP_WORDS), max_features=100)
X_train_countvec = countvec.fit_transform(X_train)
X_test_countvec = countvec.transform(X_test)

# %%
X_train_tfidf.shape, X_test_tfidf.shape
# Out:
# ((6788, 100), (4526, 100))

# %%
X_train_countvec.shape, X_test_countvec.shape
# Out:
# ((6788, 100), (4526, 100))

# %% [markdown]
# ### Experimenting ML Pipelines

# %%
algos = {'nb': BernoulliNB(), 'mlp': MLPClassifier(), 'knn': KNeighborsClassifier(), 'sgd': SGDClassifier()}
for algo, clf in algos.items():
    print(algo)
    clf.fit(X_train_tfidf, y_train_tr)
    print('Train score: ', clf.score(X_train_tfidf, y_train_tr))
    print('Test score: ', clf.score(X_test_tfidf, y_test_tr))
    print('\n\n')
# Out:
# nb
# Train score:  0.37315851502651737
# Test score:  0.3393725143614671
#
#
#
# mlp
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Train score:  0.5847083087802003
# Test score:  0.40300486080424214
#
#
#
# knn
# Train score:  0.5870654095462581
# Test score:  0.3623508616880248
#
#
#
# sgd
# Train score:  0.3601944608131998
# Test score:  0.32456915598762703

# %%
algos = {'nb': BernoulliNB(), 'mlp': MLPClassifier(), 'knn': KNeighborsClassifier(), 'sgd': SGDClassifier()}
for algo, clf in algos.items():
    print(algo)
    clf.fit(X_train_countvec, y_train_tr)
    print('Train score: ', clf.score(X_train_countvec, y_train_tr))
    print('Test score: ', clf.score(X_test_countvec, y_test_tr))
    print('\n\n')
# Out:
# nb
# Train score:  0.37315851502651737
# Test score:  0.3393725143614671
#
#
#
# mlp
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Train score:  0.7953741897466117
# Test score:  0.3654441007512152
#
#
#
# knn
# Train score:  0.5302003535651149
# Test score:  0.2761820592134335
#
#
#
# sgd
# Train score:  0.2869770182675309
# Test score:  0.2534246575342466

# %% [markdown]
# ### E2E ML Pipeline

# %%
newsgroups = fetch_20newsgroups(subset='train')
X_train, X_test, y_train, y_test = train_test_split(newsgroups.data, newsgroups.target, test_size=0.4, random_state=42)

le = LabelEncoder()
y_train_tr = le.fit_transform(y_train)
y_test_tr = le.transform(y_test)

countvec = CountVectorizer(stop_words=list(ENGLISH_STOP_WORDS), max_features=250)
X_train_countvec = countvec.fit_transform(X_train)
X_test_countvec = countvec.transform(X_test)

nb = BernoulliNB()
nb.fit(X_train_countvec, y_train_tr)
# Out:
# BernoulliNB()

# %%
y_test_hat = nb.predict(X_test_countvec)

# %%
print(classification_report(y_test_tr, y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.42      0.44       180
#            1       0.48      0.44      0.46       220
#            2       0.66      0.58      0.62       230
#            3       0.53      0.30      0.38       241
#            4       0.22      0.24      0.23       231
#            5       0.60      0.53      0.56       233
#            6       0.24      0.77      0.37       224
#            7       0.55      0.40      0.46       252
#            8       0.31      0.36      0.33       259
#            9       0.41      0.48      0.44       223
#           10       0.66      0.52      0.58       216
#           11       0.72      0.65      0.68       259
#           12       0.45      0.36      0.40       247
#           13       0.41      0.38      0.39       231
#           14       0.67      0.55      0.60       238
#           15       0.65      0.73      0.69       241
#           16       0.61      0.51      0.56       238
#           17       0.72      0.54      0.62       227
#           18       0.38      0.35      0.36       188
#           19       0.49      0.28      0.36       148
#
#     accuracy                           0.47      4526
#    macro avg       0.51      0.47      0.48      4526
# weighted avg       0.51      0.47      0.48      4526

# %%
feature_names = countvec.get_feature_names_out()
df_prob = pd.DataFrame(np.exp(nb.feature_log_prob_), index=newsgroups.target_names, columns=feature_names)

# %%
for i, row in df_prob.iterrows():
    print(i)
    print(row.sort_values(ascending=False).head(10))
    print('\n\n')
# Out:
# alt.atheism
# subject         0.996689
# lines           0.996689
# organization    0.937086
# edu             0.847682
# writes          0.821192
# article         0.625828
# posting         0.509934
# host            0.470199
# nntp            0.460265
# com             0.453642
# Name: alt.atheism, dtype: float64
#
#
#
# comp.graphics
# lines           0.997268
# subject         0.997268
# organization    0.959016
# edu             0.560109
# posting         0.494536
# host            0.464481
# nntp            0.453552
# university      0.442623
# graphics        0.346995
# writes          0.327869
# Name: comp.graphics, dtype: float64
#
#
#
# comp.os.ms-windows.misc
# subject         0.997245
# lines           0.994490
# organization    0.975207
# windows         0.669421
# edu             0.652893
# university      0.471074
# posting         0.410468
# host            0.402204
# nntp            0.396694
# writes          0.366391
# Name: comp.os.ms-windows.misc, dtype: float64
#
#
#
# comp.sys.ibm.pc.hardware
# subject         0.997151
# lines           0.991453
# organization    0.982906
# edu             0.555556
# posting         0.475783
# host            0.464387
# nntp            0.452991
# university      0.427350
# com             0.401709
# writes          0.358974
# Name: comp.sys.ibm.pc.hardware, dtype: float64
#
#
#
# comp.sys.mac.hardware
# lines           0.997135
# subject         0.997135
# organization    0.962751
# edu             0.679083
# posting         0.573066
# host            0.538682
# nntp            0.538682
# university      0.472779
# writes          0.398281
# article         0.352436
# Name: comp.sys.mac.hardware, dtype: float64
#
#
#
# comp.windows.x
# subject         0.997238
# lines           0.994475
# organization    0.980663
# host            0.527624
# posting         0.508287
# edu             0.502762
# nntp            0.494475
# com             0.447514
# use             0.312155
# thanks          0.309392
# Name: comp.windows.x, dtype: float64
#
#
#
# misc.forsale
# subject         0.997245
# lines           0.997245
# organization    0.972452
# edu             0.696970
# university      0.501377
# posting         0.451791
# nntp            0.435262
# distribution    0.432507
# host            0.432507
# new             0.300275
# Name: misc.forsale, dtype: float64
#
#
#
# rec.autos
# subject         0.997093
# lines           0.997093
# organization    0.968023
# edu             0.610465
# com             0.569767
# car             0.549419
# writes          0.549419
# article         0.549419
# posting         0.494186
# host            0.468023
# Name: rec.autos, dtype: float64
#
#
#
# rec.motorcycles
# subject         0.997067
# lines           0.994135
# organization    0.982405
# writes          0.615836
# com             0.612903
# article         0.589443
# posting         0.542522
# host            0.533724
# nntp            0.527859
# edu             0.504399
# Name: rec.motorcycles, dtype: float64
#
#
#
# rec.sport.baseball
# subject         0.997340
# organization    0.992021
# lines           0.989362
# edu             0.851064
# writes          0.563830
# article         0.537234
# university      0.494681
# posting         0.468085
# nntp            0.465426
# host            0.465426
# Name: rec.sport.baseball, dtype: float64
#
#
#
# rec.sport.hockey
# subject         0.997409
# lines           0.992228
# organization    0.984456
# edu             0.593264
# university      0.559585
# writes          0.536269
# posting         0.471503
# nntp            0.453368
# host            0.453368
# team            0.448187
# Name: rec.sport.hockey, dtype: float64
#
#
#
# sci.crypt
# subject         0.997041
# lines           0.994083
# organization    0.934911
# com             0.668639
# writes          0.603550
# key             0.532544
# edu             0.517751
# chip            0.494083
# encryption      0.476331
# posting         0.458580
# Name: sci.crypt, dtype: float64
#
#
#
# sci.electronics
# lines           0.997110
# subject         0.997110
# organization    0.968208
# edu             0.598266
# posting         0.462428
# host            0.456647
# nntp            0.453757
# writes          0.407514
# article         0.381503
# com             0.378613
# Name: sci.electronics, dtype: float64
#
#
#
# sci.med
# subject         0.997260
# lines           0.978082
# organization    0.969863
# edu             0.682192
# writes          0.564384
# article         0.561644
# com             0.542466
# posting         0.391781
# know            0.364384
# host            0.361644
# Name: sci.med, dtype: float64
#
#
#
# sci.space
# subject         0.997199
# lines           0.997199
# organization    0.957983
# edu             0.691877
# writes          0.579832
# article         0.540616
# posting         0.529412
# space           0.512605
# host            0.498599
# nntp            0.495798
# Name: sci.space, dtype: float64
#
#
#
# soc.religion.christian
# subject         0.997222
# lines           0.997222
# organization    0.888889
# edu             0.769444
# writes          0.569444
# god             0.558333
# people          0.508333
# know            0.436111
# article         0.411111
# just            0.408333
# Name: soc.religion.christian, dtype: float64
#
#
#
# talk.politics.guns
# subject         0.996774
# lines           0.990323
# organization    0.954839
# edu             0.716129
# writes          0.635484
# com             0.567742
# posting         0.567742
# article         0.558065
# host            0.554839
# nntp            0.551613
# Name: talk.politics.guns, dtype: float64
#
#
#
# talk.politics.mideast
# subject         0.997050
# lines           0.985251
# organization    0.828909
# writes          0.707965
# edu             0.684366
# article         0.637168
# people          0.501475
# israel          0.415929
# posting         0.404130
# university      0.395280
# Name: talk.politics.mideast, dtype: float64
#
#
#
# talk.politics.misc
# lines           0.996416
# subject         0.996416
# organization    0.978495
# writes          0.763441
# article         0.749104
# edu             0.702509
# com             0.616487
# don             0.465950
# posting         0.451613
# people          0.451613
# Name: talk.politics.misc, dtype: float64
#
#
#
# talk.religion.misc
# subject         0.995671
# lines           0.995671
# organization    0.961039
# edu             0.683983
# writes          0.683983
# article         0.597403
# com             0.588745
# don             0.450216
# god             0.415584
# think           0.380952
# Name: talk.religion.misc, dtype: float64

# %%
newsgroups = fetch_20newsgroups(subset='train')
X_train, X_test, y_train, y_test = train_test_split(newsgroups.data, newsgroups.target, test_size=0.4, random_state=42)

le = LabelEncoder()
y_train_tr = le.fit_transform(y_train)
y_test_tr = le.transform(y_test)

stop_words = list(ENGLISH_STOP_WORDS) + ['subject', 'lines', 'organization', 'edu', 'com', 'writes', 'article', 'posting', 'nntp', 'like', 'host', 'university']
countvec = CountVectorizer(stop_words=stop_words, max_features=250)
X_train_countvec = countvec.fit_transform(X_train)
X_test_countvec = countvec.transform(X_test)

nb = BernoulliNB()
nb.fit(X_train_countvec, y_train_tr)
y_test_hat = nb.predict(X_test_countvec)

# %%
print(classification_report(y_test_tr, y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.42      0.43       180
#            1       0.50      0.44      0.47       220
#            2       0.70      0.64      0.67       230
#            3       0.55      0.37      0.45       241
#            4       0.50      0.42      0.45       231
#            5       0.64      0.59      0.61       233
#            6       0.23      0.76      0.35       224
#            7       0.56      0.43      0.49       252
#            8       0.30      0.36      0.33       259
#            9       0.43      0.48      0.45       223
#           10       0.66      0.55      0.60       216
#           11       0.72      0.63      0.67       259
#           12       0.43      0.36      0.39       247
#           13       0.41      0.39      0.40       231
#           14       0.68      0.55      0.61       238
#           15       0.67      0.59      0.63       241
#           16       0.62      0.52      0.56       238
#           17       0.71      0.57      0.63       227
#           18       0.40      0.35      0.37       188
#           19       0.55      0.32      0.41       148
#
#     accuracy                           0.49      4526
#    macro avg       0.53      0.49      0.50      4526
# weighted avg       0.54      0.49      0.50      4526

# %%
feature_names = countvec.get_feature_names_out()
df_prob = pd.DataFrame(np.exp(nb.feature_log_prob_), index=newsgroups.target_names, columns=feature_names)

# %%
term_dict = {}
for i, row in df_prob.iterrows():
    top10_terms = row.sort_values(ascending=False).head(10)
    print(i)
    print(top10_terms)
    print('\n\n')
    for t in top10_terms.index:
        if t in term_dict.keys():
            term_dict[t]+=1
        else:
            term_dict[t] = 1
# Out:
# alt.atheism
# don       0.440397
# people    0.417219
# god       0.377483
# think     0.377483
# say       0.364238
# just      0.364238
# know      0.307947
# does      0.304636
# said      0.274834
# world     0.254967
# Name: alt.atheism, dtype: float64
#
#
#
# comp.graphics
# graphics    0.346995
# know        0.319672
# thanks      0.316940
# does        0.270492
# help        0.234973
# use         0.232240
# need        0.229508
# just        0.226776
# don         0.210383
# program     0.202186
# Name: comp.graphics, dtype: float64
#
#
#
# comp.os.ms-windows.misc
# windows         0.669421
# use             0.314050
# know            0.297521
# using           0.294766
# thanks          0.292011
# does            0.269972
# file            0.256198
# reply           0.242424
# just            0.242424
# distribution    0.234160
# Name: comp.os.ms-windows.misc, dtype: float64
#
#
#
# comp.sys.ibm.pc.hardware
# thanks          0.324786
# just            0.310541
# does            0.304843
# know            0.304843
# use             0.296296
# drive           0.273504
# computer        0.259259
# card            0.247863
# don             0.245014
# distribution    0.242165
# Name: comp.sys.ibm.pc.hardware, dtype: float64
#
#
#
# comp.sys.mac.hardware
# mac             0.369628
# know            0.335244
# apple           0.315186
# does            0.303725
# distribution    0.272206
# thanks          0.266476
# don             0.249284
# just            0.226361
# new             0.220630
# use             0.220630
# Name: comp.sys.mac.hardware, dtype: float64
#
#
#
# comp.windows.x
# use        0.312155
# thanks     0.309392
# reply      0.306630
# window     0.290055
# know       0.284530
# using      0.273481
# problem    0.262431
# does       0.262431
# mit        0.240331
# help       0.237569
# Name: comp.windows.x, dtype: float64
#
#
#
# misc.forsale
# distribution    0.432507
# new             0.300275
# mail            0.275482
# usa             0.264463
# 10              0.220386
# email           0.206612
# computer        0.201102
# used            0.190083
# reply           0.181818
# 25              0.165289
# Name: misc.forsale, dtype: float64
#
#
#
# rec.autos
# car             0.549419
# just            0.348837
# distribution    0.319767
# don             0.311047
# good            0.279070
# usa             0.273256
# think           0.270349
# know            0.244186
# time            0.238372
# new             0.238372
# Name: rec.autos, dtype: float64
#
#
#
# rec.motorcycles
# just            0.369501
# don             0.316716
# know            0.281525
# ca              0.255132
# distribution    0.252199
# good            0.249267
# think           0.217009
# new             0.214076
# ve              0.208211
# time            0.199413
# Name: rec.motorcycles, dtype: float64
#
#
#
# rec.sport.baseball
# year            0.311170
# don             0.303191
# think           0.303191
# good            0.279255
# just            0.271277
# distribution    0.242021
# game            0.239362
# team            0.239362
# know            0.234043
# games           0.226064
# Name: rec.sport.baseball, dtype: float64
#
#
#
# rec.sport.hockey
# team     0.448187
# ca       0.417098
# game     0.398964
# just     0.297927
# play     0.295337
# think    0.292746
# good     0.292746
# time     0.272021
# don      0.269430
# year     0.259067
# Name: rec.sport.hockey, dtype: float64
#
#
#
# sci.crypt
# key             0.532544
# chip            0.494083
# encryption      0.476331
# just            0.417160
# use             0.378698
# distribution    0.372781
# government      0.363905
# don             0.313609
# public          0.310651
# good            0.307692
# Name: sci.crypt, dtype: float64
#
#
#
# sci.electronics
# know      0.341040
# use       0.329480
# does      0.294798
# don       0.289017
# need      0.265896
# just      0.260116
# used      0.236994
# thanks    0.228324
# good      0.225434
# work      0.216763
# Name: sci.electronics, dtype: float64
#
#
#
# sci.med
# know      0.364384
# don       0.320548
# people    0.301370
# reply     0.295890
# just      0.295890
# think     0.276712
# time      0.263014
# cs        0.249315
# good      0.238356
# does      0.232877
# Name: sci.med, dtype: float64
#
#
#
# sci.space
# space           0.512605
# just            0.403361
# nasa            0.302521
# distribution    0.266106
# don             0.260504
# think           0.249300
# know            0.243697
# new             0.229692
# long            0.221289
# world           0.218487
# Name: sci.space, dtype: float64
#
#
#
# soc.religion.christian
# god       0.558333
# people    0.508333
# know      0.436111
# just      0.408333
# think     0.402778
# don       0.400000
# say       0.377778
# does      0.366667
# 1993      0.366667
# time      0.341667
# Name: soc.religion.christian, dtype: float64
#
#
#
# talk.politics.guns
# people          0.477419
# gun             0.448387
# don             0.432258
# just            0.393548
# think           0.361290
# distribution    0.361290
# time            0.312903
# good            0.290323
# usa             0.287097
# know            0.287097
# Name: talk.politics.guns, dtype: float64
#
#
#
# talk.politics.mideast
# people        0.501475
# israel        0.415929
# just          0.377581
# think         0.339233
# world         0.330383
# don           0.321534
# know          0.300885
# government    0.289086
# time          0.286136
# years         0.283186
# Name: talk.politics.mideast, dtype: float64
#
#
#
# talk.politics.misc
# don           0.465950
# people        0.451613
# just          0.437276
# think         0.344086
# state         0.311828
# make          0.308244
# new           0.290323
# know          0.279570
# government    0.268817
# news          0.268817
# Name: talk.politics.misc, dtype: float64
#
#
#
# talk.religion.misc
# don          0.450216
# god          0.415584
# think        0.380952
# people       0.372294
# just         0.372294
# christian    0.363636
# know         0.359307
# does         0.329004
# say          0.324675
# world        0.303030
# Name: talk.religion.misc, dtype: float64

# %%
term_dict
# Out:
# {'don': 17,
#  'people': 7,
#  'god': 3,
#  'think': 12,
#  'say': 3,
#  'just': 18,
#  'know': 17,
#  'does': 10,
#  'said': 1,
#  'world': 4,
#  'graphics': 1,
#  'thanks': 6,
#  'help': 2,
#  'use': 7,
#  'need': 2,
#  'program': 1,
#  'windows': 1,
#  'using': 2,
#  'file': 1,
#  'reply': 4,
#  'distribution': 10,
#  'drive': 1,
#  'computer': 2,
#  'card': 1,
#  'mac': 1,
#  'apple': 1,
#  'new': 6,
#  'window': 1,
#  'problem': 1,
#  'mit': 1,
#  'mail': 1,
#  'usa': 3,
#  '10': 1,
#  'email': 1,
#  'used': 2,
#  '25': 1,
#  'car': 1,
#  'good': 8,
#  'time': 7,
#  'ca': 2,
#  've': 1,
#  'year': 2,
#  'game': 2,
#  'team': 2,
#  'games': 1,
#  'play': 1,
#  'key': 1,
#  'chip': 1,
#  'encryption': 1,
#  'government': 3,
#  'public': 1,
#  'work': 1,
#  'cs': 1,
#  'space': 1,
#  'nasa': 1,
#  'long': 1,
#  '1993': 1,
#  'gun': 1,
#  'israel': 1,
#  'years': 1,
#  'state': 1,
#  'make': 1,
#  'news': 1,
#  'christian': 1}
